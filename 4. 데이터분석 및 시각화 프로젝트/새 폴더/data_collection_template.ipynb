# %% [markdown]
# # [데이터 명세]

# %% [markdown]
# ## [spotify의 음악 데이터]

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# spotify의 wed API인 spotipy에서 id, uri를 통해 제공하는 track, album, artist, playlist로 데이터를 불러옴

# %% [markdown]
# ### 2. 수집 방법

# %% [markdown]
# * 웹 API: spotify에서 제공하는 <u>spotify</u>를 이용하여 원하는 parameter를 보내여 원하는 datatime의 데이터를 가져옴.
#
# * spotipy.Spotify를 이용하여 데이터를 json을 받아옴
#
# * Spotify.charts사이트에서 제공하는 일간 또는 주간 차트 데이터(.csv)
#    - 트랙의 순위, uri 그리고 strams을 제공함.
#    - 크롤링이나 스크래핑이 금지되있음.
#    - https://charts.spotify.com/charts/overview/global

# %% [markdown]
# ### 3.   수집 경로

# %% [markdown]
# * spotipy에서 제공하는 웹API 패키지인 spotipy를 이용하여 데이터를 수집
# * Spotify.charts 사이트를 이용한 글로벌 또는 국가별 주간, 일간 차트를 통해 uri로 데이터 수집.

# %% [markdown]
# ### 4.   데이터의 논리적 구조

# %% [markdown]
# ## 게임 사운드트랙 데이터
#
# ### joined_reindex_df2
# ```
# Int64Index: 8136 entries, 0 to 8144
# Data columns (total 46 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   album_track       8136 non-null   object
#  1   track_name        8136 non-null   object
#  2   album_id          8136 non-null   object
#  3   album_name        8136 non-null   object
#  4   RPG               8136 non-null   float64
#  5   공포_genre          8136 non-null   float64
#  6   로그라이크             8136 non-null   float64
#  7   배틀로얄              8136 non-null   float64
#  8   생존                8136 non-null   float64
#  9   스토리               8136 non-null   float64
#  10  스포츠               8136 non-null   float64
#  11  슈팅                8136 non-null   float64
#  12  시뮬레이션             8136 non-null   float64
#  13  액션                8136 non-null   float64
#  14  어드벤쳐              8136 non-null   float64
#  15  잠입                8136 non-null   float64
#  16  전략                8136 non-null   float64
#  17  퍼즐                8136 non-null   float64
#  18  플랫포머              8136 non-null   float64
#  19  SF                8136 non-null   float64
#  20  공포_vibe           8136 non-null   float64
#  21  귀여운               8136 non-null   float64
#  22  근현대               8136 non-null   float64
#  23  다크판타지             8136 non-null   float64
#  24  동양                8136 non-null   float64
#  25  릴랙싱               8136 non-null   float64
#  26  미스터리              8136 non-null   float64
#  27  복고풍               8136 non-null   float64
#  28  신화                8136 non-null   float64
#  29  아포칼립스             8136 non-null   float64
#  30  애니메이션             8136 non-null   float64
#  31  유머                8136 non-null   float64
#  32  중세                8136 non-null   float64
#  33  판타지               8136 non-null   float64
#  34  펑크                8136 non-null   float64
#  35  현대                8136 non-null   float64
#  36  danceability      8136 non-null   float64
#  37  energy            8136 non-null   float64
#  38  loudness          8136 non-null   float64
#  39  speechiness       8136 non-null   float64
#  40  acousticness      8136 non-null   float64
#  41  instrumentalness  8136 non-null   float64
#  42  liveness          8136 non-null   float64
#  43  valence           8136 non-null   float64
#  44  tempo             8136 non-null   float64
#  45  track_popularity  8136 non-null   int64
# dtypes: float64(41), int64(1), object(4)
# ```

# %% [markdown]
# ### 5.   데이터의 물리적 저장 구조
