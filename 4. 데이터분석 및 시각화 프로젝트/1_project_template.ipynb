# %% [markdown]
# # [spotify 음악 데이터 수집]

# %% [markdown]
# *   기간: 2023-05-26 ~ 2023-06-01 (총 4일)
# *   리더: 이진호
# *   정의: spotify의 API를 이용하여 음악 데이터를 수집 후 분석
# *   목적: 장르별 음악의 특징을 비교 그 장르에서 인기의 특징을 분석
# *   범위: searsh를 통해 2021년 무작위 음악, 게임 game soundtrack album에 들어있는 음악, 리듬게임 playlist 음악들 등

# %% [markdown]
# ## [할 일 목록]

# %% [markdown]
# ### [1일차]

# %% [markdown]
# #### 1.  **데이터 수집 함수화 하기.**

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# #### 2. **플레이 리스트 목록만들기**

# %% [markdown]
# ### [2일차]

# %% [markdown]
# #### 1. **데이터 전처리**

# %% [markdown]
# - 음악의 특징 정보와, track_id, track_popularity을 합쳐 하나의 데이터프레임으로 만듬
# - 그룹으로 나눌 gener정보와 vibe정보를 steam의 태그를 참조하여 맵핑

# %% [markdown]
# #### 2. **각 장르별 음악의 상괸계수와 분포 그래프 만들기**

# %% [markdown]
# #### 3. **대중음악과 게임의 장르별 음악의 차이를 보기 위해 t-test를 진행**

# %% [markdown]
# 필요할 경우 상세 설명을 기술합니다.

# %% [markdown]
# ### [3일차]

# %% [markdown]
# #### 1.  **상관계수와 t-test를 통한 변수선택**

# %% [markdown]
# #### 2.  **track_popularity와 각 성분이 얼마나 영향을 미치는지 회귀분석**

# %% [markdown]
# #### 3. **데이터를 좀 더 상세히 나누기.**

# %% [markdown]
# 스팀의 게임 태그를 참조하여 작성

# %% [markdown]
# #### 4. **더 좋은 변수선택이 있을지 검토하기**

# %% [markdown]
# ### [4일차]

# %% [markdown]
# #### 1.  **데이터 시각화 하기**

# %% [markdown]
# #### 2.  **시연용 쥬피터 만들기**

# %% [markdown]
# #### 3.  **ppt 작성**

# %% [markdown]
# ## [이슈 항목]

# %% [markdown]
# ### 1.  ~~사운드트렉 매핑 문재~~

# %% [markdown]
# 대부분의 변수를 사용하는 경우 변수선택의 문제가 있을 수 있음
#
# fps와 tps는 인칭정보이지 게임 장르가 아님
#
# 아포칼립스가 배경인 게임은 따로 분류해야함.
#
# 판타지도 일반적인 판타지와 다크판타지 나눠야함
#
# 근현대, 근대 배경에 큰 차이가 없고 너무 주관적임 근현대로 합쳐야함.
#
# -----------------------------------------------------
#
# 재 매핑 후 좀더 의미있는 회귀분석결과가 나옴.
