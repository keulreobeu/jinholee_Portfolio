# %% [markdown]
# # [데이터 명세]

# %% [markdown]
# ## [kaggle: "Tabular Playground Series - Feb 2022"]

# %% [markdown]
# ### 1.   데이터 정의

# %% [markdown]
# kaggle의 "Tabular Playground Series - Feb 2022"competitions에서 제공하는 박테리아 유전정보 데이터셋

# %% [markdown]
# ### 2. 수집 방법

# %% [markdown]
# * kaggle의 competitions: "Tabular Playground Series - Feb 2022" 에서 제공하는 데이터를 CSV로 다운받음
# * smaple_submission.csv, test.csv, train.csv 총 3개의 파일로 총 1.87G

# %% [markdown]
# ### 3.   수집 경로

# %% [markdown]
# * https://www.kaggle.com/competitions/tabular-playground-series-feb-2022
#
# * data에서 CSV를 다운로드

# %% [markdown]
# ### 4.   데이터의 논리적 구조

# %% [markdown]
# 총 288컬럼으로
#
# row_id와 target인 2개의 행,
#
# 나머진 유전자의 ATGC의 구성 갯수를 컬럼으로 만들어져 있고,
#
# 모든 조합의 수는 286개 모두 컬럼으로 구성되있다.
#
# row_id는 int, target은 str 나머지 286컬럼은 float로 구성

# %% [markdown]
# ### 5.   데이터의 물리적 저장 구조

# %% [markdown]
# ![shape.PNG](attachment:shape.PNG)
